# %% [markdown]
# ### What skills are developers most excited to learn, and how has that "hype" shifted from 2019 to 2024?

# %% [markdown]
# We'll start by looking at the "developer voice" from the Stack Overflow surveys. This shows what skills are trending and gaining momentum among peers. This is the "hype" that graduates will hear about.

# %% [markdown]
# How has the gap between 'Developer Hype' (what they want), 'Employer Hiring' (what's posted), and 'Reported Dollars' (what pays) changed, and what does it mean for a new graduate

# %%
import pandas as pd
import altair as alt
